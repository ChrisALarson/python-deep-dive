# %%
import sys

# %%
for key in sorted(sys.modules.keys()):
    print(key)
# Out:
# IPython
# IPython.core
# IPython.core.alias
# IPython.core.application
# IPython.core.async_helpers
# IPython.core.autocall
# IPython.core.builtin_trap
# IPython.core.compilerop
# IPython.core.completer
# IPython.core.completerlib
# IPython.core.crashhandler
# IPython.core.debugger
# IPython.core.display
# IPython.core.display_trap
# IPython.core.displayhook
# IPython.core.displaypub
# IPython.core.error
# IPython.core.events
# IPython.core.excolors
# IPython.core.extensions
# IPython.core.formatters
# IPython.core.getipython
# IPython.core.history
# IPython.core.hooks
# IPython.core.inputtransformer2
# IPython.core.interactiveshell
# IPython.core.latex_symbols
# IPython.core.logger
# IPython.core.macro
# IPython.core.magic
# IPython.core.magic_arguments
# IPython.core.magics
# IPython.core.magics.auto
# IPython.core.magics.basic
# IPython.core.magics.code
# IPython.core.magics.config
# IPython.core.magics.display
# IPython.core.magics.execution
# IPython.core.magics.extension
# ...

# %%
'cmath' in sys.modules
# Out:
# False

# %%
'cmath' in globals()
# Out:
# False

# %%
from cmath import exp

# %%
'cmath' in globals() # cmath is not present in namespace
# Out:
# False

# %%
'exp' in globals()
# Out:
# True

# %%
'cmath' in sys.modules # BUT, cmath IS in sys modules - entire module gets loaded, but only 'exp' is in our namespace
# Out:
# True

# %%
exp
# Out:
# <function cmath.exp(z, /)>

# %%
# adding to namespace manually
cmath = sys.modules['cmath']

# %%
'cmath' in globals()
# Out:
# True

# %%
cmath.pi
# Out:
# 3.141592653589793

# %%
from cmath import * # adds ALL cmath symbols to our namespace - dangerous; we could easily overwrite by mistake

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import sys',
#   'for key in sorted(sys.modules.keys()):\n    print(key)',
#   "'cmath' in sys.modules",
#   "'cmath' in globals()",
#   'from cmath import exp',
#   "'cmath' in globals()",
#   "'exp' in globals()",
#   "'cmath' in sys.modules()",
#   "'cmath' in sys.modules",
#   'exp',
#   'exp',
#   "# adding to namespace manually\ncmath = sys.modules['cmath']",
#   "'cmath' in globals()",
#   'cmath.pi',
#   'from cmath import * # adds ALL cmath symbols to our namespace - dangerous; we could easily overwrite by mistake',
#   'globals()'],
#  '_oh': {3: False,
#   4: False,
#   6: False,
#   7: True,
#   9: True,
#   10: <function cmath.exp(z, /)>,
#   11: <function cmath.exp(z, /)>,
# ...

# %%
from math import * # now we've overwritten sin, etc. to math's version instead of cmath's

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import sys',
#   'for key in sorted(sys.modules.keys()):\n    print(key)',
#   "'cmath' in sys.modules",
#   "'cmath' in globals()",
#   'from cmath import exp',
#   "'cmath' in globals()",
#   "'exp' in globals()",
#   "'cmath' in sys.modules()",
#   "'cmath' in sys.modules",
#   'exp',
#   'exp',
#   "# adding to namespace manually\ncmath = sys.modules['cmath']",
#   "'cmath' in globals()",
#   'cmath.pi',
#   'from cmath import * # adds ALL cmath symbols to our namespace - dangerous; we could easily overwrite by mistake',
#   'globals()',
#   'from math import *',
#   'globals()'],
#  '_oh': {3: False,
#   4: False,
#   6: False,
#   7: True,
#   9: True,
# ...
